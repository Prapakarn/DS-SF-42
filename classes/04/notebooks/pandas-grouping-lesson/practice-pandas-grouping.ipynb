# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Practice Grouping Data with Pandas
#
# _Authors: Kiefer Katovich (SF), Dave Yerrington (SF), Mario Carrillo (SF)_
#
# ---
#
# You are going to investigate UFO sightings around the US.  This lab will give you practice performing `groupby` operations to split data along multiple dimensions and investigate patterns between subsets of the data using basic aggregation.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# #### 1. Load and print the header for the UFO data.

# %%
df = pd.read_csv('./datasets/ufo.csv')
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df.shape
# Out:
# (80543, 5)

# %%
# A

df.columns
# Out:
# Index([u'City', u'Colors Reported', u'Shape Reported', u'State', u'Time'], dtype='object')

# %% [markdown]
# #### 2. How many null values exist per column?

# %%
# A:
df.isnull().sum()
# Out:
# City                  47
# Colors Reported    63509
# Shape Reported      8402
# State                  0
# Time                   0
# dtype: int64

# %%
df.fillna(0)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca               0       TRIANGLE    NY
# 1               Willingboro               0          OTHER    NJ
# 2                   Holyoke               0           OVAL    CO
# 3                   Abilene               0           DISK    KS
# 4      New York Worlds Fair               0          LIGHT    NY
# 5               Valley City               0           DISK    ND
# 6               Crater Lake               0         CIRCLE    CA
# 7                      Alma               0           DISK    MI
# 8                   Eklutna               0          CIGAR    AK
# 9                   Hubbard               0       CYLINDER    OR
# 10                  Fontana               0          LIGHT    CA
# 11                 Waterloo               0       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# 13                   Keokuk               0           OVAL    IA
# 14                Ludington               0           DISK    MI
# 15              Forest Home               0         CIRCLE    CA
# 16              Los Angeles               0              0    CA
# 17                Hapeville               0              0    GA
# 18                   Oneida               0      RECTANGLE    TN
# 19               Bering Sea             RED          OTHER    AK
# 20                 Nebraska               0           DISK    NE
# 21                        0               0              0    LA
# 22                        0               0          LIGHT    LA
# 23                Owensboro               0      RECTANGLE    KY
# 24               Wilderness               0           DISK    WV
# 25                San Diego               0          CIGAR    CA
# 26               Wilderness               0           DISK    WV
# 27                   Clovis               0           DISK    NM
# 28               Los Alamos               0           DISK    NM
# 29             Ft. Duschene               0           DISK    UT
# ...                     ...             ...            ...   ...
# 80513            Manahawkin               0         CIRCLE    NJ
# 80514           New Bedford               0          LIGHT    MA
# 80515            Woodbridge               0       TRIANGLE    VA
# 80516              Glendale               0       CYLINDER    CA
# 80517               Laconia               0          CIGAR    NH
# 80518             Langhorne               0          OTHER    PA
# 80519            Glen Ellyn             RED         CIRCLE    IL
# 80520            Waynesburg               0          FLASH    PA
# 80521      Canal Winchester               0       TRIANGLE    OH
# 80522              Lawrence          ORANGE          LIGHT    MA
# 80523         Ellicott City               0          LIGHT    MD
# 80524               Olympia             RED          LIGHT    WA
# 80525             Iowa City            BLUE          LIGHT    IA
# 80526            Marshfield               0          LIGHT    MA
# 80527               Seattle               0        DIAMOND    WA
# 80528        North Royalton             RED       TRIANGLE    OH
# 80529             Deer Park               0          LIGHT    WA
# 80530         Glen St. Mary               0           DISK    FL
# 80531              Abingdon               0         CIRCLE    VA
# 80532              Lawrence               0          LIGHT    MA
# 80533             Melbourne               0           OVAL    IA
# 80534              Burleson               0          LIGHT    TX
# 80535         Elizabethtown               0         CIRCLE    KY
# 80536               Wyoming             RED           DISK    PA
# 80537                Neligh               0         CIRCLE    NE
# 80538                Neligh               0         CIRCLE    NE
# 80539          Uhrichsville               0          LIGHT    OH
# 80540                Tucson        RED BLUE              0    AZ
# 80541           Orland park             RED          LIGHT    IL
# 80542              Loughman               0          LIGHT    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# 5       9/15/1934 15:30
# 6        6/15/1935 0:00
# 7        7/15/1936 0:00
# 8      10/15/1936 17:00
# 9        6/15/1937 0:00
# 10      8/15/1937 21:00
# 11       6/1/1939 20:00
# 12      6/30/1939 20:00
# 13        7/7/1939 2:00
# 14       6/1/1941 13:00
# 15       7/2/1941 11:30
# 16       2/25/1942 0:00
# 17       6/1/1942 22:30
# 18       7/15/1942 1:00
# 19      4/30/1943 23:00
# 20       6/1/1943 15:00
# 21       8/15/1943 0:00
# 22       8/15/1943 0:00
# 23     10/15/1943 11:00
# 24       1/1/1944 10:00
# 25       1/1/1944 12:00
# 26       1/1/1944 12:00
# 27       4/2/1944 11:00
# 28       6/1/1944 12:00
# 29      6/30/1944 10:00
# ...                 ...
# 80513     9/4/2014 8:30
# 80514     9/4/2014 9:47
# 80515    9/4/2014 16:30
# 80516    9/4/2014 17:38
# 80517    9/4/2014 19:02
# 80518    9/4/2014 19:30
# 80519    9/4/2014 20:20
# 80520    9/4/2014 20:25
# 80521    9/4/2014 20:30
# 80522    9/4/2014 20:30
# 80523    9/4/2014 20:45
# 80524    9/4/2014 21:10
# 80525    9/4/2014 21:11
# 80526    9/4/2014 21:15
# 80527    9/4/2014 21:15
# 80528    9/4/2014 21:30
# 80529    9/4/2014 22:00
# 80530    9/4/2014 22:00
# 80531    9/4/2014 22:05
# 80532    9/4/2014 22:15
# 80533    9/4/2014 22:15
# 80534    9/4/2014 22:30
# 80535    9/4/2014 22:30
# 80536    9/4/2014 23:00
# 80537    9/4/2014 23:20
# 80538    9/4/2014 23:20
# 80539     9/5/2014 1:14
# 80540     9/5/2014 2:40
# 80541     9/5/2014 3:43
# 80542     9/5/2014 5:30
#
# [80543 rows x 5 columns]

# %% [markdown]
# #### 3. Which city has the most observations?

# %%
# A:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80543 entries, 0 to 80542
# Data columns (total 5 columns):
# City               80496 non-null object
# Colors Reported    17034 non-null object
# Shape Reported     72141 non-null object
# State              80543 non-null object
# Time               80543 non-null object
# dtypes: object(5)
# memory usage: 3.1+ MB

# %%
df.groupby("City").size().sort_values(ascending=False).head(10)
# Out:
# City
# Seattle          646
# New York City    612
# Phoenix          533
# Las Vegas        442
# Portland         438
# Los Angeles      416
# San Diego        401
# Houston          340
# Chicago          337
# Miami            279
# dtype: int64

# %% [markdown]
# #### 4. What is the observation count per shape?

# %%
# A:
df.groupby("Shape Reported").size().sort_values(ascending=False).head(10)
# Out:
# Shape Reported
# LIGHT        16332
# TRIANGLE      7816
# CIRCLE        7725
# FIREBALL      6249
# OTHER         5506
# SPHERE        5231
# DISK          5226
# OVAL          3721
# FORMATION     2405
# CIGAR         1983
# dtype: int64

# %% [markdown]
# #### 5. Create a subset of the data that is the top 5 cities and the top 5 shapes.

# %%
# A:
def top_cities(data):
     top_value=df.groupby("City").size().sort_values(ascending=False).head(10)
        return top_value
# Out:
#   File "<ipython-input-47-6d45d6c6af41>", line 4
#     return top_value
#     ^
# IndentationError: unexpected indent

# %%
top_cities(df)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-40-5a10b60e7190> in <module>()
# ----> 1 top_cities(df)
#
# <ipython-input-39-32a176604419> in top_cities(data)
#       2 def top_cities(data):
#       3     df.groupby("City").size().sort_values(ascending=False)
# ----> 4     subset = df[df['City']]
#       5     return data.head(5)
#
# C:\Users\prapa\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# C:\Users\prapa\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_array(self, key)
#    1983     def _getitem_array(self, key):
#    1984         # also raises Exception if object array with NA values
# -> 1985         if com.is_bool_indexer(key):
#    1986             # warning here just in case -- previously __setitem__ was
#    1987             # reindexing but __getitem__ was not; it seems more reasonable to
#
# C:\Users\prapa\Anaconda2\lib\site-packages\pandas\core\common.pyc in is_bool_indexer(key)
#     187             if not lib.is_bool_array(key):
#     188                 if isnull(key).any():
# --> 189                     raise ValueError('cannot index with vector containing '
#     190                                      'NA / NaN values')
#     191                 return False
#
# ValueError: cannot index with vector containing NA / NaN values

# %% [markdown]
# #### 6. With the subset, find the percent of each shape seen by city.

# %%
# A:

# %% [markdown]
# **7. Make a grouped bar chart with your subset data showing counts of shapes seen by city.**

# %%
# A:
